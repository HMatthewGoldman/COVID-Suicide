# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import sweetviz as sv
import numpy as np
import os
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
import chardet
import datetime as dt

# %% [markdown]
# ## Import Data

# %%
df1=pd.read_excel(r"C:\Users\drmat\OneDrive\Documents\Career Foundry\COVID_Suicide\02 Data\01 Raw\Suicide\2019-Public Health Impact Suicide.xlsx", sheet_name='Ethnicity_1', index_col=False)

# %%
df2=pd.read_excel(r"C:\Users\drmat\OneDrive\Documents\Career Foundry\COVID_Suicide\02 Data\01 Raw\Suicide\2020-Public Health Impact Suicide.xlsx", sheet_name='Ethnicity_1', index_col=False)

# %%
df3=pd.read_excel(r"C:\Users\drmat\OneDrive\Documents\Career Foundry\COVID_Suicide\02 Data\01 Raw\Suicide\2021-Public Health Impact Suicide.xlsx", sheet_name='Ethnicity_1', index_col=False)

# %% [markdown]
# ## Merge Dataframes

# %%
# use concat to merge all 3 dataframes
age_frames=[df1,df2,df3]
df=pd.concat(age_frames, axis=0)
df.reset_index()
# Out:
#      index  Edition  Report Type                   Measure Name  \
# 0        0     2019  2019 Annual  American Indian/Alaska Native
# 1        1     2019  2019 Annual  American Indian/Alaska Native
# 2        2     2019  2019 Annual  American Indian/Alaska Native
# 3        3     2019  2019 Annual  American Indian/Alaska Native
# 4        4     2019  2019 Annual  American Indian/Alaska Native
# ..     ...      ...          ...                            ...
# 775    255     2021  2021 Annual                          White
# 776    256     2021  2021 Annual                          White
# 777    257     2021  2021 Annual                          White
# 778    258     2021  2021 Annual                          White
# 779    259     2021  2021 Annual                          White
#
#                State Name  Rank  Value  Score  Lower CI  Upper CI  \
# 0                 Alabama   NaN    NaN    NaN       NaN       NaN
# 1                  Alaska   NaN   54.2    NaN      69.4      41.7
# 2                 Arizona   NaN   26.6    NaN      33.0      21.2
# 3                Arkansas   NaN    NaN    NaN       NaN       NaN
# 4              California   NaN   17.2    NaN      23.8      12.0
# ..                    ...   ...    ...    ...       ...       ...
# 775         West Virginia  24.0   19.0   0.20      21.1      16.9
# 776             Wisconsin  10.0   15.4  -0.59      16.5      14.3
# 777               Wyoming  50.0   30.7   2.00      35.6      25.8
# 778         United States   NaN   18.1    NaN      18.3      17.9
# 779  District of Columbia   NaN    NaN    NaN      11.6       3.9
#
#                                         Source  Source Year
# 0    CDC WONDER, Multiple Cause of Death Files       2017.0
# 1    CDC WONDER, Multiple Cause of Death Files       2017.0
# 2    CDC WONDER, Multiple Cause of Death Files       2017.0
# 3    CDC WONDER, Multiple Cause of Death Files       2017.0
# 4    CDC WONDER, Multiple Cause of Death Files       2017.0
# ..                                         ...          ...
# 775                                   AHR data          NaN
# 776                                   AHR data          NaN
# 777                                   AHR data          NaN
# 778                                   AHR data          NaN
# 779                                   AHR data          NaN
#
# [780 rows x 12 columns]

# %% [markdown]
# ## Inspect Dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 780 entries, 0 to 259
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Edition       780 non-null    int64
#  1   Report Type   780 non-null    object
#  2   Measure Name  780 non-null    object
#  3   State Name    780 non-null    object
#  4   Rank          150 non-null    float64
#  5   Value         438 non-null    float64
#  6   Score         50 non-null     float64
#  7   Lower CI      525 non-null    float64
#  8   Upper CI      525 non-null    float64
#  9   Source        780 non-null    object
#  10  Source Year   260 non-null    float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 73.1+ KB

# %% [markdown]
# ## Clean Dataframe

# %%
#Drop/remove irrelevant column(s)  
df.drop(columns = ['Report Type','Rank','Score','Lower CI','Upper CI','Source','Source Year'],inplace=True)

# %%
df.head()
# Out:
#    Edition                   Measure Name  State Name  Value
# 0     2019  American Indian/Alaska Native     Alabama    NaN
# 1     2019  American Indian/Alaska Native      Alaska   54.2
# 2     2019  American Indian/Alaska Native     Arizona   26.6
# 3     2019  American Indian/Alaska Native    Arkansas    NaN
# 4     2019  American Indian/Alaska Native  California   17.2

# %%
# rename columns to match other dataframes
df.rename(columns={df.columns[0]:'year',df.columns[1]:'ethnicity',df.columns[2]:'state',df.columns[3]:'suicide_deaths'},inplace=True)

# %%
# reorder dataframe to match other dataframes
df.iloc[:, [0,2,1,3]]
# Out:
#      year                 state                      ethnicity  suicide_deaths
# 0    2019               Alabama  American Indian/Alaska Native             NaN
# 1    2019                Alaska  American Indian/Alaska Native            54.2
# 2    2019               Arizona  American Indian/Alaska Native            26.6
# 3    2019              Arkansas  American Indian/Alaska Native             NaN
# 4    2019            California  American Indian/Alaska Native            17.2
# ..    ...                   ...                            ...             ...
# 255  2021         West Virginia                          White            19.0
# 256  2021             Wisconsin                          White            15.4
# 257  2021               Wyoming                          White            30.7
# 258  2021         United States                          White            18.1
# 259  2021  District of Columbia                          White             NaN
#
# [780 rows x 4 columns]

# %%
#find rows with null vaues
df.isnull().sum()
# Out:
# year                0
# ethnicity           0
# state               0
# suicide_deaths    342
# dtype: int64

# %%
#find percent of null values per row
total_rows= len(df)
total_missing_rows = df.isnull().sum()
percent_missing_per_row = round((total_missing_rows/total_rows)* 100,2)
percent_missing_per_row[percent_missing_per_row > 0]
# Out:
# suicide_deaths    43.85
# dtype: float64

# %%
# impute missing values with median
df['suicide_deaths'].fillna(df['suicide_deaths'].median(),inplace=True)

# %%
# recheck rows with null vaues
df.isnull().sum()
# Out:
# year              0
# ethnicity         0
# state             0
# suicide_deaths    0
# dtype: int64

# %%
# check unique value counts
df['year'].value_counts()
# Out:
# 2019    260
# 2020    260
# 2021    260
# Name: year, dtype: int64

# %%
# check unique value counts
df['state'].value_counts().sort_index(ascending=True)
# Out:
# Alabama                 15
# Alaska                  15
# Arizona                 15
# Arkansas                15
# California              15
# Colorado                15
# Connecticut             15
# Delaware                15
# District of Columbia    15
# Florida                 15
# Georgia                 15
# Hawaii                  15
# Idaho                   15
# Illinois                15
# Indiana                 15
# Iowa                    15
# Kansas                  15
# Kentucky                15
# Louisiana               15
# Maine                   15
# Maryland                15
# Massachusetts           15
# Michigan                15
# Minnesota               15
# Mississippi             15
# Missouri                15
# Montana                 15
# Nebraska                15
# Nevada                  15
# New Hampshire           15
# New Jersey              15
# New Mexico              15
# New York                15
# North Carolina          15
# North Dakota            15
# Ohio                    15
# Oklahoma                15
# Oregon                  15
# Pennsylvania            15
# Rhode Island            15
# South Carolina          15
# South Dakota            15
# Tennessee               15
# Texas                   15
# United States           15
# Utah                    15
# Vermont                 15
# Virginia                15
# Washington              15
# West Virginia           15
# Wisconsin               15
# Wyoming                 15
# Name: state, dtype: int64

# %%
# check unique value counts
df['ethnicity'].value_counts().sort_index(ascending=True)
# Out:
# American Indian/Alaska Native    156
# Asian/Pacific Islander           156
# Black                            156
# Hispanic                         156
# White                            156
# Name: ethnicity, dtype: int64

# %%
# check descriptive statistics of suicide_deaths column
round(df['suicide_deaths'].describe(),2)
# Out:
# count    780.00
# mean      12.35
# std        6.45
# min        3.40
# 25%        9.50
# 50%       10.80
# 75%       11.92
# max       66.80
# Name: suicide_deaths, dtype: float64

# %%
# check for outliers
# create a function to find outliers using IQR

def find_outliers_IQR(df):

   q1=df.quantile(0.25)

   q3=df.quantile(0.75)

   IQR=q3-q1

   outliers = df[((df<(q1-1.5*IQR)) | (df>(q3+1.5*IQR)))]

   return outliers

# %%
# run defined function on suicide_deaths column
outliers = find_outliers_IQR(df['suicide_deaths'])

print('number of outliers: '+ str(len(outliers)))

print('max outlier value: '+ str(outliers.max()))

print('min outlier value: '+ str(outliers.min()))

outliers
# Out:
# number of outliers: 203
# max outlier value: 66.8
# min outlier value: 3.4
# 1      54.2
# 2      26.6
# 4      17.2
# 23     28.6
# 26     41.7
#        ...
# 253    16.9
# 254    18.9
# 255    19.0
# 257    30.7
# 258    18.1
# Name: suicide_deaths, Length: 203, dtype: float64

# %%
# remove outliers by imputing with mean
# create a function to impute the mean
def impute_outliers_IQR(df):

   q1=df.quantile(0.25)

   q3=df.quantile(0.75)

   IQR=q3-q1

   upper = df[~(df>(q3+1.5*IQR))].max()

   lower = df[~(df<(q1-1.5*IQR))].min()

   df = np.where(df > upper,

       df.mean(),

       np.where(

           df < lower,

           df.mean(),

           df

           )

       )

   return df

# %%
# run defined function on ouliers in suicide_deaths column
df['suicide_deaths'] = impute_outliers_IQR(df['suicide_deaths'])

# %%
# recheck descriptive statistics of suicide_deaths column
round(df['suicide_deaths'].describe(),2)
# Out:
# count    780.00
# mean      10.69
# std        1.86
# min        5.90
# 25%       10.80
# 50%       10.80
# 75%       12.35
# max       15.40
# Name: suicide_deaths, dtype: float64

# %%
# create dataframe groups to match other dataframes
dfgroup=df.groupby(['year','state','ethnicity'])[['suicide_deaths']].agg('sum')

# %%
# round suicide_deaths to 2 decimal placed
dfgroup['suicide_deaths']=dfgroup['suicide_deaths'].round(2)

# %%
# check grouping dataframe
dfgroup.head(50)
# Out:
#                                                          suicide_deaths
# year state                ethnicity
# 2019 Alabama              American Indian/Alaska Native           10.80
#                           Asian/Pacific Islander                  10.80
#                           Black                                   12.35
#                           Hispanic                                10.80
#                           White                                   12.35
#      Alaska               American Indian/Alaska Native           12.35
#                           Asian/Pacific Islander                  10.80
#                           Black                                   10.80
#                           Hispanic                                10.80
#                           White                                   12.35
#      Arizona              American Indian/Alaska Native           12.35
#                           Asian/Pacific Islander                  10.10
#                           Black                                   10.80
#                           Hispanic                                 8.90
#                           White                                   12.35
#      Arkansas             American Indian/Alaska Native           10.80
#                           Asian/Pacific Islander                  10.80
#                           Black                                    7.70
#                           Hispanic                                10.80
#                           White                                   12.35
#      California           American Indian/Alaska Native           12.35
#                           Asian/Pacific Islander                   6.60
#                           Black                                    7.40
#                           Hispanic                                 6.00
#                           White                                   12.35
#      Colorado             American Indian/Alaska Native           10.80
#                           Asian/Pacific Islander                  11.10
#                           Black                                   10.90
#                           Hispanic                                15.10
#                           White                                   12.35
#      Connecticut          American Indian/Alaska Native           10.80
#                           Asian/Pacific Islander                  10.80
#                           Black                                    7.50
#                           Hispanic                                10.80
#                           White                                   13.60
#      Delaware             American Indian/Alaska Native           10.80
#                           Asian/Pacific Islander                  10.80
#                           Black                                   10.80
#                           Hispanic                                10.80
#                           White                                   12.35
#      District of Columbia American Indian/Alaska Native           10.80
#                           Asian/Pacific Islander                  10.80
#                           Black                                    6.50
#                           Hispanic                                10.80
#                           White                                    8.50
#      Florida              American Indian/Alaska Native           10.80
#                           Asian/Pacific Islander                   7.10
#                           Black                                   12.35
#                           Hispanic                                 7.40
#                           White                                   12.35

# %%
#Use sweetviz to generate report
my_report = sv.analyze(df)
my_report.show_html('Ethnicity Suicides 2019-2021.html')
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report Ethnicity Suicides 2019-2021.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
